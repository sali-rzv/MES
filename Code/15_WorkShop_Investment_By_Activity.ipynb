# %%
import pandas as pd
import yaml

pd.set_option('display.max_columns', None)

with open('../Settings.yaml', 'r') as file:
    Setting = yaml.safe_load(file)

Data = []

for year in range(Setting['Start_Year'], Setting['End_Year'] + 1):
    if year <= 1400 :
        file_name = f"Y{year}_10AndMore.xlsx"
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T09 = pd.read_excel(file_path, sheet_name='T09', skiprows=1)
        T09 = T09.rename(columns={
        'سال':'Year',
        'سطح کد فعالیت':'Industry_Category_Code',
        'کد فعالیت':'Industry_Code',
        ' فعالیت':'Industry_Name',
        'خرید یا تحصیل اموال سرمایه‌ای (داخلی و خارجی)': 'Capital_Purchase_Property_DF.total',
        'Unnamed: 5':'Capital_Purchase_Property_DF.machine' ,
        'Unnamed: 6': 'Capital_Purchase_Property_DF.durable',
        'Unnamed: 7': 'Capital_Purchase_Property_DF.administrative',
        'Unnamed: 8': 'Capital_Purchase_Property_DF.vehicle',
        'Unnamed: 9': 'Capital_Purchase_Property_DF.building',
        'Unnamed: 10': 'Capital_Purchase_Property_DF.land',
        'Unnamed: 11': 'Capital_Purchase_Property_DF.software',
        'Unnamed: 12': 'Capital_Purchase_Property_DF.hardware',
        'خرید یا تحصیل اموال سرمایه‌ای خارجی': 'Capital_Purchase_Property_F.total',
        'Unnamed: 14': 'Capital_Purchase_Property_F.machine',
        'Unnamed: 15': 'Capital_Purchase_Property_F.durable' ,
        'Unnamed: 16' : 'Capital_Purchase_Property_F.administrative',
        'Unnamed: 17': 'Capital_Purchase_Property_F.vehicle',
        'Unnamed: 18': 'Capital_Purchase_Property_F.building',
        'Unnamed: 19': 'Capital_Purchase_Property_F.software',
        'Unnamed: 20': 'Capital_Purchase_Property_F.hardware',
        'ساخت یا ایجاد و تعمیر اساسی اموال سرمایه‌ای توسط کارگاه':'Capital_Maintenance_Property_W.total',
        'Unnamed: 22':'Capital_Maintenance_Property_W.machine',
        'Unnamed: 23':'Capital_Maintenance_Property_W.durable', 
        'Unnamed: 24':'Capital_Maintenance_Property_W.administrative', 
        'Unnamed: 25':'Capital_Maintenance_Property_W.vehicle',
        'Unnamed: 26':'Capital_Maintenance_Property_W.building',
        'Unnamed: 27':'Capital_Maintenance_Property_W.software', 
        'Unnamed: 28':'Capital_Maintenance_Property_W.hardware',
        'تعمیرات اساسی اموال سرمایه‌ای توسط دیگران':'Capital_Maintenance_Property_O.total', 
        'Unnamed: 30':'Capital_Maintenance_Property_O.machine',
        'Unnamed: 31':'Capital_Maintenance_Property_O.durable', 
        'Unnamed: 32':'Capital_Maintenance_Property_O.administrative',
        'Unnamed: 33':'Capital_Maintenance_Property_O.vehicle', 
        'Unnamed: 34':'Capital_Maintenance_Property_O.building',
        'Unnamed: 35':'Capital_Maintenance_Property_O.software', 
        'فروش یا انتقال اموال سرمایه‌ای':'Capital_Sell_Property.total',
        'Unnamed: 37':'Capital_Sell_Property.machine',
        'Unnamed: 38':'Capital_Sell_Property.durable',
        'Unnamed: 39':'Capital_Sell_Property.administrative',
        'Unnamed: 40':'Capital_Sell_Property.vehicle',
        'Unnamed: 41':'Capital_Sell_Property.building',
        'Unnamed: 42':'Capital_Sell_Property.land',
        'Unnamed: 43':'Capital_Sell_Property.software', 
        'Unnamed: 44':'Capital_Sell_Property.hardware'
        })
        T09 = T09[T09['Year'] != 0]
        Data.append(T09)

    elif year == 1401:
        file_name = f"Y{year}_10AndMore.xlsx"
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T09 = pd.read_excel(file_path, sheet_name='T09', skiprows=2)
        T09 = T09.rename(columns={
        'سال':'Year',
        'سطح کد فعالیت':'Industry_Category_Code',
        'کد فعالیت':'Industry_Code',
        ' فعالیت':'Industry_Name',
        'خرید یا تحصیل اموال سرمایه‌ای (داخلی و خارجی)': 'Capital_Purchase_Property_DF.total',
        'Unnamed: 5':'Capital_Purchase_Property_DF.machine' ,
        'Unnamed: 6': 'Capital_Purchase_Property_DF.durable',
        'Unnamed: 7': 'Capital_Purchase_Property_DF.administrative',
        'Unnamed: 8': 'Capital_Purchase_Property_DF.vehicle',
        'Unnamed: 9': 'Capital_Purchase_Property_DF.building',
        'Unnamed: 10': 'Capital_Purchase_Property_DF.land',
        'Unnamed: 11': 'Capital_Purchase_Property_DF.software',
        'Unnamed: 12': 'Capital_Purchase_Property_DF.hardware',
        'خرید یا تحصیل اموال سرمایه‌ای خارجی': 'Capital_Purchase_Property_F.total',
        'Unnamed: 14': 'Capital_Purchase_Property_F.machine',
        'Unnamed: 15': 'Capital_Purchase_Property_F.durable' ,
        'Unnamed: 16' : 'Capital_Purchase_Property_F.administrative',
        'Unnamed: 17': 'Capital_Purchase_Property_F.vehicle',
        'Unnamed: 18': 'Capital_Purchase_Property_F.building',
        'Unnamed: 19': 'Capital_Purchase_Property_F.software',
        'Unnamed: 20': 'Capital_Purchase_Property_F.hardware',
        'ساخت یا ایجاد و تعمیر اساسی اموال سرمایه‌ای توسط کارگاه':'Capital_Maintenance_Property_W.total',
        'Unnamed: 22':'Capital_Maintenance_Property_W.machine',
        'Unnamed: 23':'Capital_Maintenance_Property_W.durable', 
        'Unnamed: 24':'Capital_Maintenance_Property_W.administrative', 
        'Unnamed: 25':'Capital_Maintenance_Property_W.vehicle',
        'Unnamed: 26':'Capital_Maintenance_Property_W.building',
        'Unnamed: 27':'Capital_Maintenance_Property_W.software', 
        'Unnamed: 28':'Capital_Maintenance_Property_W.hardware',
        'تعمیرات اساسی اموال سرمایه‌ای توسط دیگران':'Capital_Maintenance_Property_O.total', 
        'Unnamed: 30':'Capital_Maintenance_Property_O.machine',
        'Unnamed: 31':'Capital_Maintenance_Property_O.durable', 
        'Unnamed: 32':'Capital_Maintenance_Property_O.administrative',
        'Unnamed: 33':'Capital_Maintenance_Property_O.vehicle', 
        'Unnamed: 34':'Capital_Maintenance_Property_O.building',
        'Unnamed: 35':'Capital_Maintenance_Property_O.software', 
        'فروش یا انتقال اموال سرمایه‌ای':'Capital_Sell_Property.total',
        'Unnamed: 37':'Capital_Sell_Property.machine',
        'Unnamed: 38':'Capital_Sell_Property.durable',
        'Unnamed: 39':'Capital_Sell_Property.administrative',
        'Unnamed: 40':'Capital_Sell_Property.vehicle',
        'Unnamed: 41':'Capital_Sell_Property.building',
        'Unnamed: 42':'Capital_Sell_Property.land',
        'Unnamed: 43':'Capital_Sell_Property.software', 
        'Unnamed: 44':'Capital_Sell_Property.hardware'
        })
        T09 = T09[T09['Year'] != 0]
        Data.append(T09)


Dataset = pd.concat(Data, ignore_index=True)
Dataset = Dataset.dropna(subset=['Year'])
output_file_name = '15_WorkShop_Investment_By_Activity.xlsx'
Dataset.to_excel(f"{Setting['Output_Path']}/{output_file_name}", index=False)
