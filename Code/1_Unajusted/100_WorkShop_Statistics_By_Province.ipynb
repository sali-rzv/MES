# %%
import pandas as pd
import yaml

pd.set_option('display.max_columns', None)

with open('../../Settings.yaml', 'r') as file:
    Setting = yaml.safe_load(file)

Data = []

for year in range(Setting['Start_Year'], Setting['End_Year'] + 1 ):
    if year <= 1396 :
        file_name = f'Y{year}_10AndMore.xlsx'
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T11 = pd.read_excel(file_path, sheet_name='T11', skiprows=1)
        T11 =   T11.rename(columns={
            'سال':'Year',
            'استان':'Province',
            'تعداد کارگاه':'Workshops_Quantity',
            'تعداد شاغلان':'Employees_Quantity',
            'Unnamed: 4':'Employees_Quantity.Male',
            'Unnamed: 5':'Employees_Quantity.Female',
            'Unnamed: 6':'Employees_Quantity.Male.Waged',
            'Unnamed: 7':'Employees_Quantity.Female.Waged',
            'Unnamed: 8':'Employees_Quantity.Male.Not.Waged',
            'Unnamed: 9':'Employees_Quantity.Female.Not.Waged',
            'جبران خدمات':'Wage_Value',
            'ارزش مواد خام و اولیه، لوازم بسته‌بندی، ابزار و وسایل کار کم دوام':'Total_Input_Value_Without_Energy',
            'Unnamed: 12':'Total_Input_Value_Without_Energy.Imported',
            'ارزش محصولات تولید شده':'Manufactured_Product_Value',
            'ارزش فروش':'Saled_Product_Value',
            'ارزش صادرات مستقیم':'Export_Value',
            'Unnamed: 16':'Export_Value.1000USD',
            'ارزش نهاده‌های فعالیت صنعتی':'Total_Input_Industrial_Activity_Value',
            '  ارزش ستانده‌های فعالیت صنعتی':'Total_Output_Industrial_Activity_Value',
            '   ارزش افزوده فعالیت صنعتی':'Total_Value_Added_Industrial_Activity',
            'ارزش خدمات غیرصنعتی':'Total_Recievible_Not_Industrial_Value',
            'Unnamed: 21':'Total_Payable_Not_Industrial_Value',
            ' مالیات غیرمستقیم و عوارض':'Indirect_Tax_Value',
            'تشکیل سرمایه':'Capital_Formation.Change.Inventory.Value',
            'Unnamed: 24':'Capital_Formation.Fixed.Value'
        })
        T11 = T11.iloc[2:]
        T11 = T11[T11['Year'] != 0] 
        Data.append(T11)

    elif  year == 1397:
     
        file_name = f'Y1397_10AndMore.xlsx'
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T11 = pd.read_excel(file_path, sheet_name='T11', skiprows=1)
        T11 = T11.drop(T11.columns[3:8], axis=1)
        T11 = T11.rename(columns={
            'سال':'Year',
            'استان':'Province',
            'تعداد کارگاه':'Workshops_Quantity',
            'تعداد شاغلان':'Employees_Quantity',
            'Unnamed: 9':'Employees_Quantity.Male',
            'Unnamed: 10':'Employees_Quantity.Female',
            'Unnamed: 11':'Employees_Quantity.Male.Waged',
            'Unnamed: 12':'Employees_Quantity.Female.Waged',
            'Unnamed: 13':'Employees_Quantity.Male.Not.Waged',
            'Unnamed: 14':'Employees_Quantity.Female.Not.Waged',
            'جبران خدمات':'Wage_Value',
            'ارزش مواد خام و اولیه، لوازم بسته‌بندی، ابزار و وسایل کار کم دوام':'Total_Input_Value_Without_Energy',
            'Unnamed: 17':'Total_Input_Value_Without_Energy.Imported',
            'ارزش محصولات تولید شده':'Manufactured_Product_Value',
            'ارزش فروش':'Saled_Product_Value',
            'ارزش صادرات مستقیم':'Export_Value',
            'Unnamed: 21':'Export_Value.1000USD',
            'ارزش نهاده‌های فعالیت صنعتی':'Total_Input_Industrial_Activity_Value',
            '  ارزش ستانده‌های فعالیت صنعتی':'Total_Output_Industrial_Activity_Value',
            '   ارزش افزوده فعالیت صنعتی':'Total_Value_Added_Industrial_Activity',
            'ارزش خدمات غیرصنعتی':'Total_Recievible_Not_Industrial_Value',
            'Unnamed: 26':'Total_Payable_Not_Industrial_Value',
            ' مالیات غیرمستقیم و عوارض':'Indirect_Tax_Value',
            'تشکیل سرمایه':'Capital_Formation.Change.Inventory.Value',
            'Unnamed: 29':'Capital_Formation.Fixed.Value'
        })
        T11 = T11.iloc[2:]
        T11 = T11[T11['Year'] != 0] 
        Data.append(T11)

    elif 1397 < year <= 1399 :
        file_name = f'Y{year}_10AndMore.xlsx'
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T11 = pd.read_excel(file_path, sheet_name='T11', skiprows=1)
        T11 = T11.drop(T11.columns[3:5], axis=1)
        T11 = T11.rename(columns={
            'سال':'Year',
            'استان':'Province',
            'تعداد کارگاه':'Workshops_Quantity',
            'تعداد شاغلان':'Employees_Quantity',
            'Unnamed: 6':'Employees_Quantity.Male',
            'Unnamed: 7':'Employees_Quantity.Female',
            'Unnamed: 8':'Employees_Quantity.Male.Waged',
            'Unnamed: 9':'Employees_Quantity.Female.Waged',
            'Unnamed: 10':'Employees_Quantity.Male.Not.Waged',
            'Unnamed: 11':'Employees_Quantity.Female.Not.Waged',
            'جبران خدمات':'Wage_Value',
            'ارزش مواد خام و اولیه، لوازم بسته‌بندی، ابزار و وسایل کار کم دوام':'Total_Input_Value_Without_Energy',
            'Unnamed: 14':'Total_Input_Value_Without_Energy.Imported',
            'ارزش محصولات تولید شده':'Manufactured_Product_Value',
            'ارزش فروش':'Saled_Product_Value',
            'ارزش صادرات مستقیم':'Export_Value',
            'Unnamed: 18':'Export_Value.1000USD',
            'ارزش نهاده‌های فعالیت صنعتی':'Total_Input_Industrial_Activity_Value',
            '  ارزش ستانده‌های فعالیت صنعتی':'Total_Output_Industrial_Activity_Value',
            '   ارزش افزوده فعالیت صنعتی':'Total_Value_Added_Industrial_Activity',
            'ارزش خدمات غیرصنعتی':'Total_Recievible_Not_Industrial_Value',
            'Unnamed: 23':'Total_Payable_Not_Industrial_Value',
            ' مالیات غیرمستقیم و عوارض':'Indirect_Tax_Value',
            'تشکیل سرمایه':'Capital_Formation.Change.Inventory.Value',
            'Unnamed: 26':'Capital_Formation.Fixed.Value'
        })

        T11 = T11.iloc[2:]
        T11 = T11[T11['Year'] != 0] 
        Data.append(T11)

    elif year == 1400 :
        file_name = f'Y{year}_10AndMore.xlsx'
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T11 = pd.read_excel(file_path, sheet_name='T11', skiprows=1)
        T11 = T11.drop(T11.columns[3:5], axis=1)
        T11 = T11.rename(columns={
                'سال':'Year',
                'استان':'Province',
                'تعداد کارگاه':'Workshops_Quantity',
                'تعداد شاغلان':'Employees_Quantity',
                'Unnamed: 6':'Employees_Quantity.Male',
                'Unnamed: 7':'Employees_Quantity.Female',
                'Unnamed: 8':'Employees_Quantity.Male.Waged',
                'Unnamed: 9':'Employees_Quantity.Female.Waged',
                'Unnamed: 10':'Employees_Quantity.Male.Not.Waged',
                'Unnamed: 11':'Employees_Quantity.Female.Not.Waged',
                'ارزش جبران خدمات':'Wage_Value',
                'ارزش مواد خام و اولیه، لوازم بسته‌بندی، ابزار و وسایل کار کم‌دوام':'Total_Input_Value_Without_Energy',
                'Unnamed: 14':'Total_Input_Value_Without_Energy.Imported',
                'ارزش محصولات تولیدشده':'Manufactured_Product_Value',
                'ارزش فروش':'Saled_Product_Value',
                'ارزش صادرات مستقیم':'Export_Value',
                'Unnamed: 18':'Export_Value.1000USD',
                'ارزش نهاده‌های فعالیت صنعتی':'Total_Input_Industrial_Activity_Value',
                '  ارزش ستانده‌های فعالیت صنعتی':'Total_Output_Industrial_Activity_Value',
                '   ارزش افزوده فعالیت صنعتی':'Total_Value_Added_Industrial_Activity',
                'ارزش خدمات غیر صنعتی':'Total_Recievible_Not_Industrial_Value',
                'Unnamed: 23':'Total_Payable_Not_Industrial_Value',
                ' مالیات غیر مستقیم و عوارض':'Indirect_Tax_Value',
                'ارزش تشکیل سرمایه':'Capital_Formation.Change.Inventory.Value',
                'Unnamed: 26':'Capital_Formation.Fixed.Value'
            })
        T11 = T11.iloc[2:]
        T11 = T11[T11['Year'] != 0] 
        Data.append(T11)

    elif year == 1401 :
        file_name = f'Y{year}_10AndMore.xlsx'
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T11 = pd.read_excel(file_path, sheet_name='T11', skiprows=2)
        T11 = T11.drop(T11.columns[3:5], axis=1)
        T11 = T11.rename(columns={
                'سال':'Year',
                'استان':'Province',
                'تعداد کارگاه':'Workshops_Quantity',
                'تعداد شاغلان':'Employees_Quantity',
                'Unnamed: 6':'Employees_Quantity.Male',
                'Unnamed: 7':'Employees_Quantity.Female',
                'Unnamed: 8':'Employees_Quantity.Male.Waged',
                'Unnamed: 9':'Employees_Quantity.Female.Waged',
                'Unnamed: 10':'Employees_Quantity.Male.Not.Waged',
                'Unnamed: 11':'Employees_Quantity.Female.Not.Waged',
                'ارزش جبران خدمات':'Wage_Value',
                'ارزش مواد خام و اولیه، لوازم بسته‌بندی، ابزار و وسایل کار کم‌دوام':'Total_Input_Value_Without_Energy',
                'Unnamed: 14':'Total_Input_Value_Without_Energy.Imported',
                'ارزش محصولات تولیدشده':'Manufactured_Product_Value',
                'ارزش فروش':'Saled_Product_Value',
                'ارزش صادرات مستقیم':'Export_Value',
                'Unnamed: 18':'Export_Value.1000USD',
                'ارزش نهاده‌های فعالیت صنعتی':'Total_Input_Industrial_Activity_Value',
                '  ارزش ستانده‌های فعالیت صنعتی':'Total_Output_Industrial_Activity_Value',
                '   ارزش افزوده فعالیت صنعتی':'Total_Value_Added_Industrial_Activity',
                'ارزش خدمات غیر صنعتی':'Total_Recievible_Not_Industrial_Value',
                'Unnamed: 23':'Total_Payable_Not_Industrial_Value',
                ' مالیات غیر مستقیم و عوارض':'Indirect_Tax_Value',
                'ارزش تشکیل سرمایه':'Capital_Formation.Change.Inventory.Value',
                'Unnamed: 26':'Capital_Formation.Fixed.Value'
            })
        T11 = T11.iloc[2:]
        T11 = T11[T11['Year'] != 0] 
        Data.append(T11)

Dataset = pd.concat(Data, ignore_index=True)

# %%
Dataset["Province"] = Dataset["Province"].replace({
"چهارمحال وبختيارئ" : "چهارمحال و بختیاری",
"اردبيل" : "اردبیل",
"ايلام" : "ایلام",
"آذربايجان شرقي" : "آذربایجان شرقی",
"آذربايجان غربي" : "آذربایجان غربی",
"خراسان جنوبي" : "خراسان جنوبی",
"خراسان رضوئ" : "خراسان رضوی",
"خراسان شمالي" : "خراسان شمالی" ,
"سيستان وبلوچستان" : "سیستان و بلوچستان" , 
"قزوين" : "قزوین" ,
"كرمان" : "کرمان" , 
"كردستان" : "کردستان",
"كرمانشاه" : "کرمانشاه" , 
"كهگيلويه وبويراحمد" : "کهگیلویه و بویراحمد" ,
"گيلان" : "گیلان" , 
"مرکزي" : "مرکزی",
"يزد" : "یزد"
}
)

# %%
province_list = [
    'کل کشور', 'آذربایجان شرقی', 'آذربایجان غربی', 'اردبیل', 'اصفهان',
    'البرز', 'ایلام', 'بوشهر', 'تهران', 'چهارمحال و بختیاری',
    'خراسان جنوبی', 'خراسان رضوی', 'خراسان شمالی', 'خوزستان', 'زنجان',
    'سمنان', 'سیستان و بلوچستان', 'فارس', 'قزوین', 'قم', 'کردستان',
    'کرمان', 'کرمانشاه', 'کهگیلویه و بویراحمد', 'گلستان', 'گیلان',
    'لرستان', 'مازندران', 'مرکزی', 'هرمزگان', 'همدان', 'یزد'
]

province_to_code = {name: idx for idx, name in enumerate(province_list)}
Dataset['Province_Code'] = Dataset['Province'].map(province_to_code)
cols = list(Dataset.columns)
cols.remove('Province_Code')
cols.insert(1, 'Province_Code')
Dataset = Dataset[cols]
Province_Codes = Dataset.iloc[:,1:3].drop_duplicates()

# %%
output_file_name = '100_WorkShop_Statistics_By_Province.xlsx'
Dataset.to_excel(f"{Setting['Output_Path_Unajusted']}/{output_file_name}", index=False)

# %%
output_file_name = '001_Province_Codes.xlsx'
Province_Codes.to_excel(f"{Setting['Output_Path_General']}/{output_file_name}", index=False)
