# %%
import pandas as pd
import yaml

pd.set_option('display.max_columns', None)

with open('../../Settings.yaml', 'r') as file:
    Setting = yaml.safe_load(file)

Data = []

for year in range(Setting['Start_Year'], Setting['End_Year'] + 1):
    if year <= 1400 :
        file_name = f"Y{year}_10AndMore.xlsx"
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T19 = pd.read_excel(file_path, sheet_name='T19', skiprows=1)
        T19 = T19.rename(columns={
        'سال':'Year',
        'استان':'Province',
        'خرید یا تحصیل اموال سرمایه‌ای (داخلی و خارجی)': 'Capital_Purchase_Property_DF.total',
        'Unnamed: 3':'Capital_Purchase_Property_DF.machine' ,
        'Unnamed: 4': 'Capital_Purchase_Property_DF.durable',
        'Unnamed: 5': 'Capital_Purchase_Property_DF.administrative',
        'Unnamed: 6': 'Capital_Purchase_Property_DF.vehicle',
        'Unnamed: 7': 'Capital_Purchase_Property_DF.building',
        'Unnamed: 8': 'Capital_Purchase_Property_DF.land',
        'Unnamed: 9': 'Capital_Purchase_Property_DF.software',
        'Unnamed: 10': 'Capital_Purchase_Property_DF.hardware',
        'خرید یا تحصیل اموال سرمایه‌ای خارجی': 'Capital_Purchase_Property_F.total',
        'Unnamed: 12': 'Capital_Purchase_Property_F.machine',
        'Unnamed: 13': 'Capital_Purchase_Property_F.durable' ,
        'Unnamed: 14' : 'Capital_Purchase_Property_F.administrative',
        'Unnamed: 15': 'Capital_Purchase_Property_F.vehicle',
        'Unnamed: 16': 'Capital_Purchase_Property_F.building',
        'Unnamed: 17': 'Capital_Purchase_Property_F.software',
        'Unnamed: 18': 'Capital_Purchase_Property_F.hardware',
        'ساخت یا ایجاد و تعمیر اساسی اموال سرمایه‌ای توسط کارگاه':'Capital_Maintenance_Property_W.total',
        'Unnamed: 20':'Capital_Maintenance_Property_W.machine',
        'Unnamed: 21':'Capital_Maintenance_Property_W.durable', 
        'Unnamed: 22':'Capital_Maintenance_Property_W.administrative', 
        'Unnamed: 23':'Capital_Maintenance_Property_W.vehicle',
        'Unnamed: 24':'Capital_Maintenance_Property_W.building',
        'Unnamed: 25':'Capital_Maintenance_Property_W.software', 
        'Unnamed: 26':'Capital_Maintenance_Property_W.hardware',
        'تعمیرات اساسی اموال سرمایه‌ای توسط دیگران':'Capital_Maintenance_Property_O.total', 
        'Unnamed: 28':'Capital_Maintenance_Property_O.machine',
        'Unnamed: 29':'Capital_Maintenance_Property_O.durable', 
        'Unnamed: 30':'Capital_Maintenance_Property_O.administrative',
        'Unnamed: 31':'Capital_Maintenance_Property_O.vehicle', 
        'Unnamed: 32':'Capital_Maintenance_Property_O.building',
        'Unnamed: 33':'Capital_Maintenance_Property_O.software', 
        'فروش یا انتقال اموال سرمایه‌ای':'Capital_Sell_Property.total',
        'Unnamed: 35':'Capital_Sell_Property.machine',
        'Unnamed: 36':'Capital_Sell_Property.durable',
        'Unnamed: 37':'Capital_Sell_Property.administrative',
        'Unnamed: 38':'Capital_Sell_Property.vehicle',
        'Unnamed: 39':'Capital_Sell_Property.building',
        'Unnamed: 40':'Capital_Sell_Property.land',
        'Unnamed: 41':'Capital_Sell_Property.software', 
        'Unnamed: 42':'Capital_Sell_Property.hardware'
        })
        T19 = T19[T19['Year'] != 0]
        Data.append(T19)
    
    elif year == 1401:
        file_name = f"Y{year}_10AndMore.xlsx"
        file_path = f"{Setting['Raw_Path']}/{file_name}"
        T19 = pd.read_excel(file_path, sheet_name='T19', skiprows=2)
        T19 = T19.rename(columns={
        'سال':'Year',
        'استان':'Province',
        'خرید یا تحصیل اموال سرمایه‌ای (داخلی و خارجی)': 'Capital_Purchase_Property_DF.total',
        'Unnamed: 3':'Capital_Purchase_Property_DF.machine' ,
        'Unnamed: 4': 'Capital_Purchase_Property_DF.durable',
        'Unnamed: 5': 'Capital_Purchase_Property_DF.administrative',
        'Unnamed: 6': 'Capital_Purchase_Property_DF.vehicle',
        'Unnamed: 7': 'Capital_Purchase_Property_DF.building',
        'Unnamed: 8': 'Capital_Purchase_Property_DF.land',
        'Unnamed: 9': 'Capital_Purchase_Property_DF.software',
        'Unnamed: 10': 'Capital_Purchase_Property_DF.hardware',
        'خرید یا تحصیل اموال سرمایه‌ای خارجی': 'Capital_Purchase_Property_F.total',
        'Unnamed: 12': 'Capital_Purchase_Property_F.machine',
        'Unnamed: 13': 'Capital_Purchase_Property_F.durable' ,
        'Unnamed: 14' : 'Capital_Purchase_Property_F.administrative',
        'Unnamed: 15': 'Capital_Purchase_Property_F.vehicle',
        'Unnamed: 16': 'Capital_Purchase_Property_F.building',
        'Unnamed: 17': 'Capital_Purchase_Property_F.software',
        'Unnamed: 18': 'Capital_Purchase_Property_F.hardware',
        'ساخت یا ایجاد و تعمیر اساسی اموال سرمایه‌ای توسط کارگاه':'Capital_Maintenance_Property_W.total',
        'Unnamed: 20':'Capital_Maintenance_Property_W.machine',
        'Unnamed: 21':'Capital_Maintenance_Property_W.durable', 
        'Unnamed: 22':'Capital_Maintenance_Property_W.administrative', 
        'Unnamed: 23':'Capital_Maintenance_Property_W.vehicle',
        'Unnamed: 24':'Capital_Maintenance_Property_W.building',
        'Unnamed: 25':'Capital_Maintenance_Property_W.software', 
        'Unnamed: 26':'Capital_Maintenance_Property_W.hardware',
        'تعمیرات اساسی اموال سرمایه‌ای توسط دیگران':'Capital_Maintenance_Property_O.total', 
        'Unnamed: 28':'Capital_Maintenance_Property_O.machine',
        'Unnamed: 29':'Capital_Maintenance_Property_O.durable', 
        'Unnamed: 30':'Capital_Maintenance_Property_O.administrative',
        'Unnamed: 31':'Capital_Maintenance_Property_O.vehicle', 
        'Unnamed: 32':'Capital_Maintenance_Property_O.building',
        'Unnamed: 33':'Capital_Maintenance_Property_O.software', 
        'فروش یا انتقال اموال سرمایه‌ای':'Capital_Sell_Property.total',
        'Unnamed: 35':'Capital_Sell_Property.machine',
        'Unnamed: 36':'Capital_Sell_Property.durable',
        'Unnamed: 37':'Capital_Sell_Property.administrative',
        'Unnamed: 38':'Capital_Sell_Property.vehicle',
        'Unnamed: 39':'Capital_Sell_Property.building',
        'Unnamed: 40':'Capital_Sell_Property.land',
        'Unnamed: 41':'Capital_Sell_Property.software', 
        'Unnamed: 42':'Capital_Sell_Property.hardware'
        })
        T19 = T19[T19['Year'] != 0]
        Data.append(T19)
    

Dataset = pd.concat(Data, ignore_index=True)
Dataset = Dataset.dropna(subset=['Year'])

Dataset["Province"] = Dataset["Province"].replace({
"چهارمحال وبختيارئ" : "چهارمحال و بختیاری",
"اردبيل" : "اردبیل",
"ايلام" : "ایلام",
"آذربايجان شرقي" : "آذربایجان شرقی",
"آذربايجان غربي" : "آذربایجان غربی",
"خراسان جنوبي" : "خراسان جنوبی",
"خراسان رضوئ" : "خراسان رضوی",
"خراسان شمالي" : "خراسان شمالی" ,
"سيستان وبلوچستان" : "سیستان و بلوچستان" , 
"قزوين" : "قزوین" ,
"كرمان" : "کرمان" , 
"كردستان" : "کردستان",
"كرمانشاه" : "کرمانشاه" , 
"كهگيلويه وبويراحمد" : "کهگیلویه و بویراحمد" ,
"گيلان" : "گیلان" , 
"مرکزي" : "مرکزی",
"يزد" : "یزد"
})

# %%
province_list = [
    'کل کشور', 'آذربایجان شرقی', 'آذربایجان غربی', 'اردبیل', 'اصفهان',
    'البرز', 'ایلام', 'بوشهر', 'تهران', 'چهارمحال و بختیاری',
    'خراسان جنوبی', 'خراسان رضوی', 'خراسان شمالی', 'خوزستان', 'زنجان',
    'سمنان', 'سیستان و بلوچستان', 'فارس', 'قزوین', 'قم', 'کردستان',
    'کرمان', 'کرمانشاه', 'کهگیلویه و بویراحمد', 'گلستان', 'گیلان',
    'لرستان', 'مازندران', 'مرکزی', 'هرمزگان', 'همدان', 'یزد'
]

province_to_code = {name: idx for idx, name in enumerate(province_list)}
Dataset['Province_Code'] = Dataset['Province'].map(province_to_code)
cols = list(Dataset.columns)
cols.remove('Province_Code')
cols.insert(1, 'Province_Code')
Dataset = Dataset[cols]
Dataset = Dataset.dropna(subset=['Year'])

# %%
output_file_name = '170_WorkShop_Investment_By_Province.xlsx'
Dataset.to_excel(f"{Setting['Output_Path_Unajusted']}/{output_file_name}", index=False)
